# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
from google.colab import drive
drive.mount('drive')
# Out:
# Mounted at drive

# %%
dataset = pd.read_csv('drive/My Drive/Machine Learning A_to_Z/Projects/Heart_Disease_Prediction.csv')
dataset
# Out:
#      Age  Sex  Chest pain type   BP  Cholesterol  FBS over 120  EKG results  \
# 0     70    1                4  130          322             0            2
# 1     67    0                3  115          564             0            2
# 2     57    1                2  124          261             0            0
# 3     64    1                4  128          263             0            0
# 4     74    0                2  120          269             0            2
# ..   ...  ...              ...  ...          ...           ...          ...
# 265   52    1                3  172          199             1            0
# 266   44    1                2  120          263             0            0
# 267   56    0                2  140          294             0            2
# 268   57    1                4  140          192             0            0
# 269   67    1                4  160          286             0            2
#
# ...

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 270 entries, 0 to 269
# Data columns (total 14 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Age                      270 non-null    int64
#  1   Sex                      270 non-null    int64
#  2   Chest pain type          270 non-null    int64
#  3   BP                       270 non-null    int64
#  4   Cholesterol              270 non-null    int64
#  5   FBS over 120             270 non-null    int64
#  6   EKG results              270 non-null    int64
#  7   Max HR                   270 non-null    int64
#  8   Exercise angina          270 non-null    int64
#  9   ST depression            270 non-null    float64
#  10  Slope of ST              270 non-null    int64
#  11  Number of vessels fluro  270 non-null    int64
#  12  Thallium                 270 non-null    int64
#  13  Heart Disease            270 non-null    object
# ...

# %%
import seaborn as sns

# %%
fig, ax = plt.subplots(figsize = (13,5))
sns.kdeplot(dataset[dataset["Heart Disease"]==1]["Age"], alpha=0.5,shade = True, color="red", label="HeartDisease", ax = ax)
sns.kdeplot(dataset[dataset["Heart Disease"]==0]["Age"], alpha=0.5,shade = True, color="green", label="Normal", ax = ax)
plt.title('Distribution of Age', fontsize = 18)
ax.set_xlabel("AGe")
ax.set_ylabel("Frequency")
ax.legend();
plt.show()
# Out:
# <ipython-input-58-103738bd7069>:2: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(dataset[dataset["Heart Disease"]==1]["Age"], alpha=0.5,shade = True, color="red", label="HeartDisease", ax = ax)
# <ipython-input-58-103738bd7069>:3: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(dataset[dataset["Heart Disease"]==0]["Age"], alpha=0.5,shade = True, color="green", label="Normal", ax = ax)

# %%
# Age Density of patients having Heart Disease is more towards 60
# Age Density of Normal Patients is distributed between 40 to 60

# %%
sns.catplot(x='Sex' , data = dataset,hue='Heart Disease' ,kind='count')

# %%
# Heart Disease is fount more in Male Patients compare to Females

# %%
sns.catplot(x='Chest pain type' , data = dataset,hue='Heart Disease' ,kind='count')

# %%
# patients having level 1 chest pain have 25% chance of Heart Disease
# patients having level 2 chest pain have 17.5% chance of Heart Disease
# patients having level 3 chest pain have 21.5% chance of Heart Disease
# patients having level 4 chest pain have 70% chance of Heart Disease

# %%
sns.catplot(x='FBS over 120' , data = dataset,hue='Heart Disease' ,kind='count')

# %%
# patients having FBS over 120 have 40% chance of having heart disease
# patients having FBS below 120 have 45% chance of having heart disease

# %%
fig, ax = plt.subplots(figsize = (13,5))
sns.kdeplot(dataset[dataset["Heart Disease"]==1]["Cholesterol"], alpha=0.5,shade = True, color="red", label="HeartDisease", ax = ax)
sns.kdeplot(dataset[dataset["Heart Disease"]==0]["Cholesterol"], alpha=0.5,shade = True, color="green", label="Normal", ax = ax)
plt.title('Distribution of Cholesterol', fontsize = 18)
ax.set_xlabel("Cholesterol")
ax.set_ylabel("Frequency")
ax.legend();
plt.show()
# Out:
# <ipython-input-59-c70dce57bf4c>:2: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(dataset[dataset["Heart Disease"]==1]["Cholesterol"], alpha=0.5,shade = True, color="red", label="HeartDisease", ax = ax)
# <ipython-input-59-c70dce57bf4c>:3: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(dataset[dataset["Heart Disease"]==0]["Cholesterol"], alpha=0.5,shade = True, color="green", label="Normal", ax = ax)

# %%
# frequency of cholesterol level in patients having heart disease in more towards 300
# while in normal patients it is dense near 200-220

# %%
fig, ax = plt.subplots(figsize = (13,5))
sns.kdeplot(dataset[dataset["Heart Disease"]==1]["BP"], alpha=0.5,shade = True, color="red", label="HeartDisease", ax = ax)
sns.kdeplot(dataset[dataset["Heart Disease"]==0]["BP"], alpha=0.5,shade = True, color="green", label="Normal", ax = ax)
plt.title('Distribution of Blood Pressure', fontsize = 18)
ax.set_xlabel("Blood Pressure")
ax.set_ylabel("Frequency")
ax.legend();
plt.show()
# Out:
# <ipython-input-60-f8eaade27986>:2: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(dataset[dataset["Heart Disease"]==1]["BP"], alpha=0.5,shade = True, color="red", label="HeartDisease", ax = ax)
# <ipython-input-60-f8eaade27986>:3: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(dataset[dataset["Heart Disease"]==0]["BP"], alpha=0.5,shade = True, color="green", label="Normal", ax = ax)

# %%
# Blood pressure looks quite similar for all patients
# for heart patients it is going till 200

# %%
fig, ax = plt.subplots(figsize = (13,5))
sns.kdeplot(dataset[dataset["Heart Disease"]==1]["Max HR"], alpha=0.5,shade = True, color="red", label="HeartDisease", ax = ax)
sns.kdeplot(dataset[dataset["Heart Disease"]==0]["Max HR"], alpha=0.5,shade = True, color="green", label="Normal", ax = ax)
plt.title('Distribution of Maximum Heart Rate', fontsize = 18)
ax.set_xlabel("Max HR")
ax.set_ylabel("Frequency")
ax.legend();
plt.show()
# Out:
# <ipython-input-61-d75dac8f6434>:2: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(dataset[dataset["Heart Disease"]==1]["Max HR"], alpha=0.5,shade = True, color="red", label="HeartDisease", ax = ax)
# <ipython-input-61-d75dac8f6434>:3: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(dataset[dataset["Heart Disease"]==0]["Max HR"], alpha=0.5,shade = True, color="green", label="Normal", ax = ax)

# %%
# Maximum heart rate shows the diffence between heart patients and normal patients
# maximum of heart patient's max Heart Rate is limited till 150 only
# whereas for normal patients max Heart Rate is going till 170-175

# %% [markdown]
# Encode variable

# %%
def encode(value):
  if value=='Presence':
    return 1;
  elif value=='Absence':
    return 0;

# %%
dataset['Heart Disease'] = dataset['Heart Disease'].apply(encode)
dataset['Heart Disease']
# Out:
# 0      1
# 1      0
# 2      1
# 3      0
# 4      0
#       ..
# 265    0
# 266    0
# 267    0
# 268    0
# 269    1
# Name: Heart Disease, Length: 270, dtype: int64

# %%
X = dataset.iloc[:,:-1].values
y = dataset.iloc[:,-1].values

# %% [markdown]
# split into training and test set

# %%
from sklearn.model_selection import train_test_split
X_train , X_test , y_train , y_test = train_test_split(X , y , test_size=0.2 , random_state=0)

# %% [markdown]
# train model on training set

# %%
from sklearn.linear_model import LinearRegression
regressor =  LinearRegression()
regressor.fit(X_train , y_train)
# Out:
# LinearRegression()

# %% [markdown]
# predicting test results

# %%
y_pred = regressor.predict(X_test)
np.set_printoptions(precision=3)
print(np.concatenate((y_pred.reshape(len(y_pred),1), y_test.reshape(len(y_test),1)),1))
# Out:
# [[ 0.345  0.   ]
#  [ 0.378  0.   ]
#  [ 0.631  0.   ]
#  [ 0.929  1.   ]
#  [ 0.143  0.   ]
#  [ 0.138  0.   ]
#  [ 0.41   1.   ]
#  [ 0.409  0.   ]
#  [ 0.393  0.   ]
#  [ 0.223  0.   ]
#  [ 0.315  0.   ]
#  [ 0.532  0.   ]
#  [ 0.511  0.   ]
#  [ 1.093  1.   ]
#  [ 0.926  1.   ]
#  [ 0.124  0.   ]
#  [ 0.114  0.   ]
#  [ 0.878  1.   ]
#  [ 0.621  1.   ]
#  [ 0.361  1.   ]
#  [ 1.407  1.   ]
#  [-0.06   0.   ]
#  [ 0.912  1.   ]
#  [ 0.67   0.   ]
#  [ 0.447  1.   ]
#  [ 0.347  0.   ]
#  [ 0.305  0.   ]
#  [ 0.116  0.   ]
#  [ 0.361  0.   ]
#  [ 0.452  1.   ]
#  [ 0.409  0.   ]
#  [ 0.369  0.   ]
#  [ 1.143  1.   ]
#  [-0.041  0.   ]
#  [ 0.768  1.   ]
#  [ 0.52   1.   ]
#  [ 1.039  1.   ]
#  [ 0.814  1.   ]
#  [-0.034  0.   ]
#  [ 0.428  1.   ]
#  [ 0.537  1.   ]
#  [ 0.075  0.   ]
#  [ 0.067  0.   ]
#  [ 0.659  1.   ]
#  [ 0.134  0.   ]
#  [ 0.014  1.   ]
#  [ 0.807  0.   ]
#  [ 0.459  0.   ]
#  [ 1.16   1.   ]
#  [ 0.697  1.   ]
#  [ 1.04   1.   ]
#  [ 0.597  0.   ]
# ...
